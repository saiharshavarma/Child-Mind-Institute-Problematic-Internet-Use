# %% [markdown]
# ## Imports and Set Up

# %%
# !pip install pytorch-tabnet
# Out:
# Requirement already satisfied: pytorch-tabnet in /opt/conda/lib/python3.10/site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.10/site-packages (from pytorch-tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-tabnet) (1.14.1)
# Requirement already satisfied: torch>=1.3 in /opt/conda/lib/python3.10/site-packages (from pytorch-tabnet) (2.4.0)
# Requirement already satisfied: tqdm>=4.36 in /opt/conda/lib/python3.10/site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.3->pytorch-tabnet) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)

# %%
import os
import random
import warnings
from concurrent.futures import ThreadPoolExecutor

from scipy.optimize import minimize

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from colorama import Fore, Style
from IPython.display import clear_output
from lightgbm import LGBMClassifier
from matplotlib import pyplot as plt
from sklearn.base import clone
from sklearn.ensemble import VotingClassifier
from sklearn.impute import KNNImputer
from sklearn.metrics import (accuracy_score, cohen_kappa_score,
                             confusion_matrix, f1_score, mean_absolute_error,
                             mean_squared_error, precision_score, recall_score,
                             classification_report)
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.base import BaseEstimator, ClassifierMixin

# %%
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
def set_seed(seed_value=2024):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed(seed_value)
    torch.backends.cudnn.deterministic = True

set_seed(2024)

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Load in Files

# %%
TRAIN_CSV = '/kaggle/input/child-mind-institute-problematic-internet-use/train.csv'
TEST_CSV = '/kaggle/input/child-mind-institute-problematic-internet-use/test.csv'
SAMPLE_SUBMISSION_CSV = '/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv'
SERIES_TRAIN_DIR = '/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet'
SERIES_TEST_DIR = '/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet'

train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)
sample_submission_df = pd.read_csv(SAMPLE_SUBMISSION_CSV)

# Drop all the PCIAT variables as they are not present in the test data
for col in train_df.columns:
    if 'PCIAT' in col:
        train_df.drop(col, axis=1, inplace=True)

# %%
# Function to process individual time series files
def process_time_series(file_name, directory):
    df = pd.read_parquet(os.path.join(directory, file_name, 'part-0.parquet'))
    df = df.drop('step', axis=1)
    stats = df.describe().values.flatten()
    record_id = file_name.split('=')[1]
    return stats, record_id

# %%
# Function to load and aggregate time series data
def load_time_series_data(directory):
    file_names = os.listdir(directory)
    stats_list = []
    ids_list = []

    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_time_series(fname, directory), file_names),
                            total=len(file_names)))

    for stats, record_id in results:
        stats_list.append(stats)
        ids_list.append(record_id)

    stats_df = pd.DataFrame(stats_list, columns=[f'stat_{i}' for i in range(len(stats_list[0]))])
    stats_df['id'] = ids_list
    return stats_df

# %%
train_series_df = load_time_series_data(SERIES_TRAIN_DIR)
test_series_df = load_time_series_data(SERIES_TEST_DIR)
# Out:
# 100%|██████████| 996/996 [01:09<00:00, 14.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]

# %% [markdown]
# ### Encoding of Time Series Data

# %%
class TimeSeriesAutoencoder(nn.Module):
    def __init__(self, input_size, encoding_size):
        super(TimeSeriesAutoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, encoding_size * 3),
            nn.ReLU(),
            nn.Linear(encoding_size * 3, encoding_size * 2),
            nn.ReLU(),
            nn.Linear(encoding_size * 2, encoding_size),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_size, input_size * 2),
            nn.ReLU(),
            nn.Linear(input_size * 2, input_size * 3),
            nn.ReLU(),
            nn.Linear(input_size * 3, input_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
def get_encoded_features(df, encoding_dim=60, epochs=100, batch_size=32):
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df)
    tensor_data = torch.FloatTensor(scaled_data)
    input_dim = tensor_data.shape[1]

    autoencoder = TimeSeriesAutoencoder(input_dim, encoding_dim)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(autoencoder.parameters())

    for epoch in range(epochs):
        for i in range(0, len(tensor_data), batch_size):
            batch = tensor_data[i:i + batch_size]
            optimizer.zero_grad()
            outputs = autoencoder(batch)
            loss = criterion(outputs, batch)
            loss.backward()
            optimizer.step()

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')

    with torch.no_grad():
        encoded_data = autoencoder.encoder(tensor_data).numpy()

    encoded_df = pd.DataFrame(encoded_data, columns=[f'Enc_{i + 1}' for i in range(encoded_data.shape[1])])
    return encoded_df

# %%
train_series_features = train_series_df.drop('id', axis=1)
test_series_features = test_series_df.drop('id', axis=1)

train_encoded = get_encoded_features(train_series_features)
test_encoded = get_encoded_features(test_series_features)

train_encoded['id'] = train_series_df['id']
test_encoded['id'] = test_series_df['id']

train_df = train_df.merge(train_encoded, on='id', how='left')
test_df = test_df.merge(test_encoded, on='id', how='left')
# Out:
# Epoch [10/100], Loss: 1.6710
# Epoch [20/100], Loss: 1.5469
# Epoch [30/100], Loss: 1.5154
# Epoch [40/100], Loss: 1.4932
# Epoch [50/100], Loss: 1.4964
# Epoch [60/100], Loss: 1.4920
# Epoch [70/100], Loss: 1.4309
# Epoch [80/100], Loss: 1.4185
# Epoch [90/100], Loss: 1.3667
# Epoch [100/100], Loss: 1.3620
# Epoch [10/100], Loss: 1.0070
# Epoch [20/100], Loss: 0.5783
# Epoch [30/100], Loss: 0.4271
# Epoch [40/100], Loss: 0.4271
# Epoch [50/100], Loss: 0.4271
# Epoch [60/100], Loss: 0.4271
# Epoch [70/100], Loss: 0.4271
# Epoch [80/100], Loss: 0.4271
# Epoch [90/100], Loss: 0.4271
# Epoch [100/100], Loss: 0.4271

# %% [markdown]
# ### Imputation of Missing Numerical Values

# %%
# Imputing missing values using KNN imputer
def impute_missing_values(df):
    imputer = KNNImputer(n_neighbors=5)
    numeric_columns = df.select_dtypes(include=['float64','float32','int64']).columns # We treat the time series data as a median for now but others could be used
    imputed_array = imputer.fit_transform(df[numeric_columns])
    imputed_df = pd.DataFrame(imputed_array, columns=numeric_columns)
    for col in df.columns:
        if col not in numeric_columns:
            imputed_df[col] = df[col]
    return imputed_df

# %%
train_df.replace([np.inf, -np.inf], np.nan, inplace=True) # Debug why we have inf values

train_df = impute_missing_values(train_df)
train_df['sii'] = train_df['sii'].round().astype(int)

# Imputation is needed in test set for some cases but not others to revisit

print(train_df.isna().sum())
# Out:
# Basic_Demos-Age           0
# Basic_Demos-Sex           0
# CGAS-CGAS_Score           0
# Physical-BMI              0
# Physical-Height           0
#                        ...
# BIA-Season             1815
# PAQ_A-Season           3485
# PAQ_C-Season           2239
# SDS-Season             1342
# PreInt_EduHx-Season     420
# Length: 120, dtype: int64

# %% [markdown]
# ### Categorical Processing

# %%
categorical_cols = list(train_df.select_dtypes(include=['object']).columns) #sii (outcome var) is categorical but we are encoding that differently
categorical_cols.remove('id')
print(categorical_cols)

def preprocess_categorical(df):
    for col in categorical_cols:
        df[col] = df[col].fillna('Missing').astype('category')
    return df

train_df = preprocess_categorical(train_df)
test_df = preprocess_categorical(test_df)


train_df = pd.get_dummies(train_df, columns = categorical_cols, drop_first=True, dtype='int')
test_df = pd.get_dummies(test_df, columns = categorical_cols, drop_first=True, dtype='int')
# Out:
# ['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season', 'Fitness_Endurance-Season', 'FGC-Season', 'BIA-Season', 'PAQ_A-Season', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season']

# %%
train_df = train_df.drop('id', axis=1)
test_df = test_df.drop('id', axis=1)

# %% [markdown]
# ## Tabnet Classifier

# %%
# Define the Quadratic Weighted Kappa metric
def quadratic_weighted_kappa(y_actual, y_predicted):
    return cohen_kappa_score(y_actual, y_predicted, weights='quadratic')

# Function to apply thresholds to continuous predictions
def apply_thresholds(predictions, thresholds):
    return np.digitize(predictions, bins=thresholds)

# Function to optimize thresholds to maximize QWK
def optimize_thresholds(y_true, predictions):
    def loss_func(thresh):
        # Ensure thresholds are sorted
        thresh_sorted = np.sort(thresh)
        preds = apply_thresholds(predictions, thresh_sorted)
        return -quadratic_weighted_kappa(y_true, preds)
    
    initial_thresholds = [0.5, 1.5, 2.5]  # Initial guesses for thresholds
    bounds = [(0, 3)] * 3  # Assuming classes are 0,1,2,3
    result = minimize(loss_func, initial_thresholds, method='Nelder-Mead')
    return result.x

def train_and_evaluate_tabnet():
    X = train_df.drop('sii', axis=1).values  # Ensure conversion to NumPy array
    y = train_df['sii'].astype(int).values  # Ensure conversion to NumPy array
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    oof_predictions = np.zeros(len(y))
    train_kappas = []
    val_kappas = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
        print(f"Training fold {fold + 1}")
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        # Check for NaNs and Infs
        assert not np.any(np.isnan(X_train)), "NaN values in X_train"
        assert not np.any(np.isinf(X_train)), "Inf values in X_train"
        assert not np.any(np.isnan(y_train)), "NaN values in y_train"
        assert not np.any(np.isinf(y_train)), "Inf values in y_train"

        assert not np.any(np.isnan(X_val)), "NaN values in X_val"
        assert not np.any(np.isinf(X_val)), "Inf values in X_val"
        assert not np.any(np.isnan(y_val)), "NaN values in y_val"
        assert not np.any(np.isinf(y_val)), "Inf values in y_val"

        # Instantiate a fresh TabNet model for each fold without multi_class
        tabnet_model = TabNetClassifier(
            n_d=64,
            n_a=64,
            n_steps=5,
            gamma=1.3,
            lambda_sparse=1e-3,
            seed=2024,
            verbose=1,
            device_name='auto'
        )

        # Fit the model with 'logloss' as eval_metric
        tabnet_model.fit(
            X_train=X_train,
            y_train=y_train,
            eval_set=[(X_val, y_val)],
            eval_name=['validation'],
            eval_metric=['logloss'],
            max_epochs=100,
            patience=20,
            batch_size=1024,
            virtual_batch_size=128,
            num_workers=0,
            drop_last=False
        )

        # Predict class probabilities
        y_train_proba = tabnet_model.predict_proba(X_train)
        y_val_proba = tabnet_model.predict_proba(X_val)

        # Compute expected values
        classes = tabnet_model.classes_
        expected_train = np.dot(y_train_proba, classes)
        expected_val = np.dot(y_val_proba, classes)

        oof_predictions[val_idx] = expected_val

        # For training kappa, use class predictions
        y_train_pred = tabnet_model.predict(X_train)
        y_val_pred = tabnet_model.predict(X_val)

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred)
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred)

        train_kappas.append(train_kappa)
        val_kappas.append(val_kappa)

        print(f"Fold {fold + 1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")

    print(f"Average Train QWK: {np.mean(train_kappas):.4f}")
    print(f"Average Validation QWK: {np.mean(val_kappas):.4f}")

    # Optimize thresholds on out-of-fold predictions
    optimal_thresholds = optimize_thresholds(y, oof_predictions)
    print(f"Optimized Thresholds: {optimal_thresholds}")

    # Apply thresholds to get final class predictions
    final_oof_predictions = apply_thresholds(oof_predictions, optimal_thresholds)
    final_kappa = quadratic_weighted_kappa(y, final_oof_predictions)
    print(f"Final Optimized QWK: {Fore.CYAN}{Style.BRIGHT}{final_kappa:.4f}{Style.RESET_ALL}")

# %%
# Train and evaluate the TabNet model
train_and_evaluate_tabnet()
# Out:
# Training fold 1
# epoch 0  | loss: 1.73061 | validation_logloss: 5.82454 |  0:00:00s
# epoch 1  | loss: 1.52725 | validation_logloss: 6.8569  |  0:00:00s
# epoch 2  | loss: 1.38984 | validation_logloss: 6.04811 |  0:00:00s
# epoch 3  | loss: 1.29843 | validation_logloss: 4.21407 |  0:00:01s
# epoch 4  | loss: 1.15212 | validation_logloss: 2.50755 |  0:00:01s
# epoch 5  | loss: 1.09846 | validation_logloss: 2.74389 |  0:00:01s
# epoch 6  | loss: 1.0482  | validation_logloss: 3.40865 |  0:00:01s
# epoch 7  | loss: 0.99975 | validation_logloss: 3.30766 |  0:00:02s
# epoch 8  | loss: 0.97599 | validation_logloss: 2.51032 |  0:00:02s
# epoch 9  | loss: 1.00769 | validation_logloss: 2.79812 |  0:00:02s
# epoch 10 | loss: 1.00574 | validation_logloss: 1.51334 |  0:00:02s
# epoch 11 | loss: 0.93997 | validation_logloss: 1.95527 |  0:00:03s
# epoch 12 | loss: 0.92701 | validation_logloss: 2.01692 |  0:00:03s
# epoch 13 | loss: 0.91967 | validation_logloss: 1.56756 |  0:00:03s
# epoch 14 | loss: 0.95559 | validation_logloss: 1.35544 |  0:00:03s
# epoch 15 | loss: 0.91753 | validation_logloss: 1.32647 |  0:00:03s
# epoch 16 | loss: 0.89803 | validation_logloss: 1.17804 |  0:00:04s
# epoch 17 | loss: 0.8937  | validation_logloss: 1.21418 |  0:00:04s
# epoch 18 | loss: 0.9185  | validation_logloss: 1.34459 |  0:00:04s
# epoch 19 | loss: 0.88106 | validation_logloss: 1.3101  |  0:00:04s
# epoch 20 | loss: 0.87803 | validation_logloss: 1.28385 |  0:00:05s
# epoch 21 | loss: 0.86402 | validation_logloss: 1.56664 |  0:00:05s
# epoch 22 | loss: 0.88471 | validation_logloss: 1.29764 |  0:00:05s
# epoch 23 | loss: 0.88326 | validation_logloss: 1.39662 |  0:00:05s
# epoch 24 | loss: 0.86295 | validation_logloss: 1.07138 |  0:00:06s
# epoch 25 | loss: 0.85884 | validation_logloss: 1.34589 |  0:00:06s
# epoch 26 | loss: 0.86856 | validation_logloss: 1.01162 |  0:00:06s
# epoch 27 | loss: 0.85583 | validation_logloss: 1.09406 |  0:00:06s
# epoch 28 | loss: 0.84253 | validation_logloss: 1.05501 |  0:00:06s
# epoch 29 | loss: 0.84046 | validation_logloss: 1.10575 |  0:00:07s
# epoch 30 | loss: 0.85775 | validation_logloss: 1.14907 |  0:00:07s
# epoch 31 | loss: 0.87017 | validation_logloss: 1.23952 |  0:00:07s
# epoch 32 | loss: 0.85125 | validation_logloss: 1.06757 |  0:00:07s
# epoch 33 | loss: 0.8625  | validation_logloss: 1.10077 |  0:00:08s
# epoch 34 | loss: 0.85751 | validation_logloss: 1.13178 |  0:00:08s
# epoch 35 | loss: 0.86166 | validation_logloss: 1.0613  |  0:00:08s
# epoch 36 | loss: 0.87507 | validation_logloss: 1.1432  |  0:00:08s
# epoch 37 | loss: 0.86351 | validation_logloss: 1.08798 |  0:00:09s
# epoch 38 | loss: 0.862   | validation_logloss: 1.04402 |  0:00:09s
# epoch 39 | loss: 0.85282 | validation_logloss: 1.03058 |  0:00:09s
# epoch 40 | loss: 0.83703 | validation_logloss: 1.03349 |  0:00:09s
# epoch 41 | loss: 0.83923 | validation_logloss: 1.07346 |  0:00:10s
# epoch 42 | loss: 0.85086 | validation_logloss: 0.97879 |  0:00:10s
# epoch 43 | loss: 0.84992 | validation_logloss: 1.04829 |  0:00:10s
# epoch 44 | loss: 0.83121 | validation_logloss: 1.03879 |  0:00:10s
# epoch 45 | loss: 0.83826 | validation_logloss: 1.04135 |  0:00:11s
# epoch 46 | loss: 0.84477 | validation_logloss: 1.05143 |  0:00:11s
# epoch 47 | loss: 0.84487 | validation_logloss: 1.03361 |  0:00:11s
# epoch 48 | loss: 0.84208 | validation_logloss: 1.07584 |  0:00:12s
# epoch 49 | loss: 0.84109 | validation_logloss: 1.09975 |  0:00:12s
# epoch 50 | loss: 0.84093 | validation_logloss: 1.01325 |  0:00:12s
# epoch 51 | loss: 0.84776 | validation_logloss: 0.94881 |  0:00:12s
# epoch 52 | loss: 0.85416 | validation_logloss: 0.97677 |  0:00:12s
# epoch 53 | loss: 0.8678  | validation_logloss: 0.94265 |  0:00:13s
# epoch 54 | loss: 0.86636 | validation_logloss: 0.9629  |  0:00:13s
# epoch 55 | loss: 0.86125 | validation_logloss: 0.9339  |  0:00:13s
# epoch 56 | loss: 0.85697 | validation_logloss: 0.95364 |  0:00:13s
# epoch 57 | loss: 0.84782 | validation_logloss: 0.95781 |  0:00:14s
# epoch 58 | loss: 0.84823 | validation_logloss: 0.95277 |  0:00:14s
# epoch 59 | loss: 0.8399  | validation_logloss: 0.98993 |  0:00:14s
# epoch 60 | loss: 0.83917 | validation_logloss: 0.91659 |  0:00:14s
# epoch 61 | loss: 0.8377  | validation_logloss: 0.93712 |  0:00:15s
# epoch 62 | loss: 0.83827 | validation_logloss: 0.9401  |  0:00:15s
# epoch 63 | loss: 0.84316 | validation_logloss: 0.95755 |  0:00:15s
# epoch 64 | loss: 0.83788 | validation_logloss: 0.93591 |  0:00:15s
# epoch 65 | loss: 0.84253 | validation_logloss: 0.93092 |  0:00:15s
# epoch 66 | loss: 0.83007 | validation_logloss: 0.94437 |  0:00:16s
# epoch 67 | loss: 0.83411 | validation_logloss: 0.9265  |  0:00:16s
# epoch 68 | loss: 0.82568 | validation_logloss: 0.94821 |  0:00:16s
# epoch 69 | loss: 0.83532 | validation_logloss: 0.93771 |  0:00:16s
# epoch 70 | loss: 0.84196 | validation_logloss: 0.91191 |  0:00:17s
# epoch 71 | loss: 0.83892 | validation_logloss: 0.92374 |  0:00:17s
# epoch 72 | loss: 0.84487 | validation_logloss: 0.90965 |  0:00:17s
# epoch 73 | loss: 0.84228 | validation_logloss: 0.9227  |  0:00:17s
# epoch 74 | loss: 0.83173 | validation_logloss: 0.92521 |  0:00:18s
# epoch 75 | loss: 0.82664 | validation_logloss: 0.92455 |  0:00:18s
# epoch 76 | loss: 0.83013 | validation_logloss: 0.92736 |  0:00:18s
# epoch 77 | loss: 0.83576 | validation_logloss: 0.91309 |  0:00:18s
# epoch 78 | loss: 0.82778 | validation_logloss: 0.91039 |  0:00:19s
# epoch 79 | loss: 0.83088 | validation_logloss: 0.91277 |  0:00:19s
# epoch 80 | loss: 0.82566 | validation_logloss: 0.89774 |  0:00:19s
# epoch 81 | loss: 0.82049 | validation_logloss: 0.89749 |  0:00:19s
# epoch 82 | loss: 0.82164 | validation_logloss: 0.91457 |  0:00:19s
# epoch 83 | loss: 0.82794 | validation_logloss: 0.91847 |  0:00:20s
# epoch 84 | loss: 0.82972 | validation_logloss: 0.92388 |  0:00:20s
# epoch 85 | loss: 0.82346 | validation_logloss: 0.8898  |  0:00:20s
# epoch 86 | loss: 0.81919 | validation_logloss: 0.90437 |  0:00:20s
# epoch 87 | loss: 0.81954 | validation_logloss: 0.87983 |  0:00:21s
# epoch 88 | loss: 0.81492 | validation_logloss: 0.88402 |  0:00:21s
# epoch 89 | loss: 0.80677 | validation_logloss: 0.88688 |  0:00:21s
# epoch 90 | loss: 0.81118 | validation_logloss: 0.88262 |  0:00:21s
# epoch 91 | loss: 0.80583 | validation_logloss: 0.88088 |  0:00:22s
# epoch 92 | loss: 0.80261 | validation_logloss: 0.87111 |  0:00:22s
# epoch 93 | loss: 0.8069  | validation_logloss: 0.88666 |  0:00:22s
# epoch 94 | loss: 0.80898 | validation_logloss: 0.87501 |  0:00:22s
# epoch 95 | loss: 0.81232 | validation_logloss: 0.8676  |  0:00:23s
# epoch 96 | loss: 0.79634 | validation_logloss: 0.88076 |  0:00:23s
# epoch 97 | loss: 0.79777 | validation_logloss: 0.89747 |  0:00:23s
# epoch 98 | loss: 0.8094  | validation_logloss: 0.92203 |  0:00:23s
# epoch 99 | loss: 0.79974 | validation_logloss: 0.94235 |  0:00:23s
# Stop training because you reached max_epochs = 100 with best_epoch = 95 and best_validation_logloss = 0.8676
# Fold 1 - Train QWK: 0.3831, Validation QWK: 0.2970
# Training fold 2
# epoch 0  | loss: 1.75081 | validation_logloss: 5.14863 |  0:00:00s
# epoch 1  | loss: 1.36563 | validation_logloss: 3.60796 |  0:00:00s
# epoch 2  | loss: 1.25793 | validation_logloss: 3.87232 |  0:00:00s
# epoch 3  | loss: 1.21595 | validation_logloss: 4.06145 |  0:00:00s
# epoch 4  | loss: 1.13977 | validation_logloss: 3.78622 |  0:00:01s
# epoch 5  | loss: 1.08125 | validation_logloss: 4.14399 |  0:00:01s
# epoch 6  | loss: 1.03144 | validation_logloss: 3.84906 |  0:00:01s
# epoch 7  | loss: 1.00139 | validation_logloss: 5.49295 |  0:00:01s
# epoch 8  | loss: 0.97492 | validation_logloss: 4.41957 |  0:00:02s
# epoch 9  | loss: 0.9964  | validation_logloss: 2.65606 |  0:00:02s
# epoch 10 | loss: 0.98023 | validation_logloss: 2.66026 |  0:00:02s
# epoch 11 | loss: 0.95157 | validation_logloss: 2.06168 |  0:00:02s
# epoch 12 | loss: 0.99185 | validation_logloss: 2.86971 |  0:00:03s
# epoch 13 | loss: 0.97685 | validation_logloss: 1.96492 |  0:00:03s
# epoch 14 | loss: 0.93647 | validation_logloss: 1.81375 |  0:00:03s
# epoch 15 | loss: 0.90846 | validation_logloss: 1.68392 |  0:00:03s
# epoch 16 | loss: 0.89501 | validation_logloss: 1.69303 |  0:00:03s
# epoch 17 | loss: 0.89731 | validation_logloss: 1.62496 |  0:00:04s
# epoch 18 | loss: 0.88897 | validation_logloss: 1.88178 |  0:00:04s
# epoch 19 | loss: 0.88755 | validation_logloss: 1.51463 |  0:00:04s
# epoch 20 | loss: 0.9058  | validation_logloss: 1.25126 |  0:00:04s
# epoch 21 | loss: 0.90076 | validation_logloss: 1.72117 |  0:00:05s
# epoch 22 | loss: 0.90893 | validation_logloss: 1.11982 |  0:00:05s
# epoch 23 | loss: 0.90344 | validation_logloss: 1.51899 |  0:00:05s
# epoch 24 | loss: 0.90125 | validation_logloss: 1.19131 |  0:00:05s
# epoch 25 | loss: 0.94143 | validation_logloss: 1.3937  |  0:00:06s
# epoch 26 | loss: 0.88998 | validation_logloss: 1.12439 |  0:00:06s
# epoch 27 | loss: 0.86168 | validation_logloss: 1.15882 |  0:00:06s
# epoch 28 | loss: 0.85776 | validation_logloss: 1.36493 |  0:00:06s
# epoch 29 | loss: 0.84816 | validation_logloss: 1.20951 |  0:00:07s
# epoch 30 | loss: 0.8563  | validation_logloss: 1.10052 |  0:00:07s
# epoch 31 | loss: 0.86754 | validation_logloss: 1.24555 |  0:00:07s
# epoch 32 | loss: 0.87798 | validation_logloss: 1.13917 |  0:00:07s
# epoch 33 | loss: 0.86829 | validation_logloss: 1.23297 |  0:00:08s
# epoch 34 | loss: 0.86397 | validation_logloss: 1.16988 |  0:00:08s
# epoch 35 | loss: 0.87289 | validation_logloss: 1.30498 |  0:00:08s
# epoch 36 | loss: 0.8714  | validation_logloss: 1.03792 |  0:00:08s
# epoch 37 | loss: 0.88752 | validation_logloss: 1.18231 |  0:00:09s
# epoch 38 | loss: 0.88596 | validation_logloss: 1.06457 |  0:00:09s
# epoch 39 | loss: 0.86247 | validation_logloss: 1.11471 |  0:00:09s
# epoch 40 | loss: 0.87117 | validation_logloss: 1.05541 |  0:00:09s
# epoch 41 | loss: 0.882   | validation_logloss: 1.08049 |  0:00:10s
# epoch 42 | loss: 0.86845 | validation_logloss: 1.03249 |  0:00:10s
# epoch 43 | loss: 0.85921 | validation_logloss: 1.06799 |  0:00:10s
# epoch 44 | loss: 0.8524  | validation_logloss: 1.16302 |  0:00:10s
# epoch 45 | loss: 0.86302 | validation_logloss: 1.01562 |  0:00:10s
# epoch 46 | loss: 0.85766 | validation_logloss: 1.0344  |  0:00:11s
# epoch 47 | loss: 0.85592 | validation_logloss: 1.06779 |  0:00:11s
# epoch 48 | loss: 0.84542 | validation_logloss: 0.9851  |  0:00:11s
# epoch 49 | loss: 0.8603  | validation_logloss: 0.99862 |  0:00:11s
# epoch 50 | loss: 0.85803 | validation_logloss: 1.00517 |  0:00:12s
# epoch 51 | loss: 0.85505 | validation_logloss: 1.00956 |  0:00:12s
# epoch 52 | loss: 0.85226 | validation_logloss: 0.98239 |  0:00:12s
# epoch 53 | loss: 0.85404 | validation_logloss: 0.9783  |  0:00:12s
# epoch 54 | loss: 0.85195 | validation_logloss: 0.98926 |  0:00:13s
# epoch 55 | loss: 0.85771 | validation_logloss: 0.95921 |  0:00:13s
# epoch 56 | loss: 0.85243 | validation_logloss: 0.97404 |  0:00:13s
# epoch 57 | loss: 0.85427 | validation_logloss: 0.95722 |  0:00:13s
# epoch 58 | loss: 0.84619 | validation_logloss: 0.94808 |  0:00:14s
# epoch 59 | loss: 0.84828 | validation_logloss: 0.95665 |  0:00:14s
# epoch 60 | loss: 0.84816 | validation_logloss: 0.97851 |  0:00:14s
# epoch 61 | loss: 0.84913 | validation_logloss: 0.95651 |  0:00:14s
# epoch 62 | loss: 0.84307 | validation_logloss: 0.97376 |  0:00:15s
# epoch 63 | loss: 0.84007 | validation_logloss: 0.95068 |  0:00:15s
# epoch 64 | loss: 0.83888 | validation_logloss: 0.91822 |  0:00:15s
# epoch 65 | loss: 0.84559 | validation_logloss: 0.92791 |  0:00:15s
# epoch 66 | loss: 0.83023 | validation_logloss: 0.92065 |  0:00:16s
# epoch 67 | loss: 0.83713 | validation_logloss: 0.97306 |  0:00:16s
# epoch 68 | loss: 0.8496  | validation_logloss: 0.9493  |  0:00:16s
# epoch 69 | loss: 0.83945 | validation_logloss: 0.94809 |  0:00:16s
# epoch 70 | loss: 0.84081 | validation_logloss: 0.94102 |  0:00:16s
# epoch 71 | loss: 0.83799 | validation_logloss: 0.9309  |  0:00:17s
# epoch 72 | loss: 0.84829 | validation_logloss: 0.94896 |  0:00:17s
# epoch 73 | loss: 0.85919 | validation_logloss: 0.93462 |  0:00:17s
# epoch 74 | loss: 0.84046 | validation_logloss: 0.95915 |  0:00:18s
# epoch 75 | loss: 0.84796 | validation_logloss: 0.9512  |  0:00:18s
# epoch 76 | loss: 0.84922 | validation_logloss: 0.94904 |  0:00:18s
# epoch 77 | loss: 0.83512 | validation_logloss: 0.93842 |  0:00:18s
# epoch 78 | loss: 0.8365  | validation_logloss: 0.93323 |  0:00:19s
# epoch 79 | loss: 0.83484 | validation_logloss: 0.94363 |  0:00:19s
# epoch 80 | loss: 0.83836 | validation_logloss: 0.94962 |  0:00:19s
# epoch 81 | loss: 0.84171 | validation_logloss: 0.93809 |  0:00:19s
# epoch 82 | loss: 0.85048 | validation_logloss: 0.94532 |  0:00:19s
# epoch 83 | loss: 0.84692 | validation_logloss: 0.94152 |  0:00:20s
# epoch 84 | loss: 0.84627 | validation_logloss: 0.94756 |  0:00:20s
#
# Early stopping occurred at epoch 84 with best_epoch = 64 and best_validation_logloss = 0.91822
# Fold 2 - Train QWK: 0.3442, Validation QWK: 0.3119
# Training fold 3
# epoch 0  | loss: 1.72683 | validation_logloss: 3.95305 |  0:00:00s
# epoch 1  | loss: 1.41905 | validation_logloss: 5.52684 |  0:00:00s
# epoch 2  | loss: 1.24114 | validation_logloss: 2.76635 |  0:00:00s
# epoch 3  | loss: 1.21702 | validation_logloss: 2.90064 |  0:00:01s
# epoch 4  | loss: 1.10767 | validation_logloss: 1.99428 |  0:00:01s
# epoch 5  | loss: 1.07503 | validation_logloss: 2.51107 |  0:00:01s
# epoch 6  | loss: 1.03706 | validation_logloss: 2.18435 |  0:00:01s
# epoch 7  | loss: 1.04354 | validation_logloss: 2.48315 |  0:00:02s
# epoch 8  | loss: 1.01559 | validation_logloss: 2.18652 |  0:00:02s
# epoch 9  | loss: 0.97491 | validation_logloss: 2.61218 |  0:00:02s
# epoch 10 | loss: 0.94264 | validation_logloss: 3.56829 |  0:00:02s
# epoch 11 | loss: 0.94933 | validation_logloss: 1.72332 |  0:00:03s
# epoch 12 | loss: 0.94094 | validation_logloss: 3.34626 |  0:00:03s
# epoch 13 | loss: 0.9376  | validation_logloss: 2.83917 |  0:00:03s
# epoch 14 | loss: 0.90848 | validation_logloss: 1.8178  |  0:00:03s
# epoch 15 | loss: 0.93698 | validation_logloss: 1.30985 |  0:00:04s
# epoch 16 | loss: 0.93945 | validation_logloss: 1.54393 |  0:00:04s
# epoch 17 | loss: 0.9438  | validation_logloss: 1.25662 |  0:00:04s
# epoch 18 | loss: 0.91935 | validation_logloss: 1.34518 |  0:00:04s
# epoch 19 | loss: 0.90122 | validation_logloss: 1.66853 |  0:00:05s
# epoch 20 | loss: 0.87782 | validation_logloss: 1.48638 |  0:00:05s
# epoch 21 | loss: 0.91213 | validation_logloss: 1.68784 |  0:00:05s
# epoch 22 | loss: 0.90459 | validation_logloss: 1.42832 |  0:00:05s
# epoch 23 | loss: 0.88404 | validation_logloss: 1.28286 |  0:00:06s
# epoch 24 | loss: 0.86976 | validation_logloss: 1.35955 |  0:00:06s
# epoch 25 | loss: 0.8846  | validation_logloss: 1.41826 |  0:00:06s
# epoch 26 | loss: 0.87111 | validation_logloss: 1.52371 |  0:00:06s
# epoch 27 | loss: 0.88318 | validation_logloss: 1.39838 |  0:00:07s
# epoch 28 | loss: 0.87926 | validation_logloss: 1.25941 |  0:00:07s
# epoch 29 | loss: 0.86647 | validation_logloss: 1.18544 |  0:00:07s
# epoch 30 | loss: 0.86648 | validation_logloss: 1.14665 |  0:00:07s
# epoch 31 | loss: 0.86544 | validation_logloss: 1.2418  |  0:00:07s
# epoch 32 | loss: 0.86823 | validation_logloss: 1.33801 |  0:00:08s
# epoch 33 | loss: 0.88824 | validation_logloss: 1.12213 |  0:00:08s
# epoch 34 | loss: 0.9129  | validation_logloss: 1.26513 |  0:00:08s
# epoch 35 | loss: 0.89505 | validation_logloss: 0.99556 |  0:00:08s
# epoch 36 | loss: 0.88494 | validation_logloss: 1.10694 |  0:00:09s
# epoch 37 | loss: 0.87353 | validation_logloss: 0.9953  |  0:00:09s
# epoch 38 | loss: 0.86885 | validation_logloss: 1.08547 |  0:00:09s
# epoch 39 | loss: 0.86583 | validation_logloss: 1.02825 |  0:00:09s
# epoch 40 | loss: 0.85298 | validation_logloss: 1.08398 |  0:00:10s
# epoch 41 | loss: 0.8478  | validation_logloss: 1.03034 |  0:00:10s
# epoch 42 | loss: 0.85096 | validation_logloss: 1.04049 |  0:00:10s
# epoch 43 | loss: 0.84268 | validation_logloss: 1.03227 |  0:00:10s
# epoch 44 | loss: 0.84155 | validation_logloss: 1.03103 |  0:00:11s
# epoch 45 | loss: 0.84154 | validation_logloss: 1.03554 |  0:00:11s
# epoch 46 | loss: 0.83679 | validation_logloss: 1.05408 |  0:00:11s
# epoch 47 | loss: 0.84494 | validation_logloss: 1.00006 |  0:00:11s
# epoch 48 | loss: 0.84534 | validation_logloss: 0.95043 |  0:00:12s
# epoch 49 | loss: 0.82656 | validation_logloss: 0.94505 |  0:00:12s
# epoch 50 | loss: 0.83332 | validation_logloss: 0.98603 |  0:00:12s
# epoch 51 | loss: 0.84183 | validation_logloss: 0.93697 |  0:00:12s
# epoch 52 | loss: 0.84078 | validation_logloss: 0.983   |  0:00:13s
# epoch 53 | loss: 0.83239 | validation_logloss: 0.90686 |  0:00:13s
# epoch 54 | loss: 0.84474 | validation_logloss: 0.97004 |  0:00:13s
# epoch 55 | loss: 0.83456 | validation_logloss: 0.93139 |  0:00:13s
# epoch 56 | loss: 0.8287  | validation_logloss: 0.98017 |  0:00:14s
# epoch 57 | loss: 0.8435  | validation_logloss: 0.91972 |  0:00:14s
# epoch 58 | loss: 0.82751 | validation_logloss: 0.90687 |  0:00:14s
# epoch 59 | loss: 0.82679 | validation_logloss: 0.92381 |  0:00:14s
# epoch 60 | loss: 0.82818 | validation_logloss: 0.91587 |  0:00:15s
# epoch 61 | loss: 0.83459 | validation_logloss: 0.88333 |  0:00:15s
# epoch 62 | loss: 0.82525 | validation_logloss: 0.88114 |  0:00:15s
# epoch 63 | loss: 0.81966 | validation_logloss: 0.87776 |  0:00:15s
# epoch 64 | loss: 0.82119 | validation_logloss: 0.88297 |  0:00:15s
# epoch 65 | loss: 0.81805 | validation_logloss: 0.87613 |  0:00:16s
# epoch 66 | loss: 0.81905 | validation_logloss: 0.90717 |  0:00:16s
# epoch 67 | loss: 0.81376 | validation_logloss: 0.93892 |  0:00:16s
# epoch 68 | loss: 0.81065 | validation_logloss: 0.8673  |  0:00:16s
# epoch 69 | loss: 0.81384 | validation_logloss: 0.86671 |  0:00:17s
# epoch 70 | loss: 0.82422 | validation_logloss: 0.85965 |  0:00:17s
# epoch 71 | loss: 0.80971 | validation_logloss: 0.86033 |  0:00:17s
# epoch 72 | loss: 0.81644 | validation_logloss: 0.88151 |  0:00:17s
# epoch 73 | loss: 0.81982 | validation_logloss: 0.88352 |  0:00:18s
# epoch 74 | loss: 0.82237 | validation_logloss: 0.90074 |  0:00:18s
# epoch 75 | loss: 0.81185 | validation_logloss: 0.87783 |  0:00:18s
# epoch 76 | loss: 0.80972 | validation_logloss: 0.88785 |  0:00:18s
# epoch 77 | loss: 0.81101 | validation_logloss: 0.87745 |  0:00:18s
# epoch 78 | loss: 0.81827 | validation_logloss: 0.875   |  0:00:19s
# epoch 79 | loss: 0.81531 | validation_logloss: 0.88267 |  0:00:19s
# epoch 80 | loss: 0.80918 | validation_logloss: 0.88229 |  0:00:19s
# epoch 81 | loss: 0.80221 | validation_logloss: 0.89091 |  0:00:19s
# epoch 82 | loss: 0.81817 | validation_logloss: 0.88084 |  0:00:20s
# epoch 83 | loss: 0.8139  | validation_logloss: 0.8927  |  0:00:20s
# epoch 84 | loss: 0.82202 | validation_logloss: 0.88593 |  0:00:20s
# epoch 85 | loss: 0.81789 | validation_logloss: 0.89309 |  0:00:20s
# epoch 86 | loss: 0.81089 | validation_logloss: 0.89649 |  0:00:21s
# epoch 87 | loss: 0.81216 | validation_logloss: 0.86193 |  0:00:21s
# epoch 88 | loss: 0.8027  | validation_logloss: 0.87245 |  0:00:21s
# epoch 89 | loss: 0.80376 | validation_logloss: 0.86272 |  0:00:21s
# epoch 90 | loss: 0.80297 | validation_logloss: 0.86153 |  0:00:21s
#
# Early stopping occurred at epoch 90 with best_epoch = 70 and best_validation_logloss = 0.85965
# Fold 3 - Train QWK: 0.4058, Validation QWK: 0.3829
# Training fold 4
# epoch 0  | loss: 1.74086 | validation_logloss: 4.94262 |  0:00:00s
# epoch 1  | loss: 1.36545 | validation_logloss: 4.25181 |  0:00:00s
# epoch 2  | loss: 1.2949  | validation_logloss: 3.09076 |  0:00:00s
# epoch 3  | loss: 1.23105 | validation_logloss: 2.81404 |  0:00:00s
# epoch 4  | loss: 1.16584 | validation_logloss: 4.01585 |  0:00:01s
# epoch 5  | loss: 1.05628 | validation_logloss: 4.37873 |  0:00:01s
# epoch 6  | loss: 1.11533 | validation_logloss: 3.21601 |  0:00:01s
# epoch 7  | loss: 1.08872 | validation_logloss: 2.45255 |  0:00:01s
# epoch 8  | loss: 1.03287 | validation_logloss: 4.30211 |  0:00:02s
# epoch 9  | loss: 1.02165 | validation_logloss: 2.28438 |  0:00:02s
# epoch 10 | loss: 1.00241 | validation_logloss: 1.92885 |  0:00:02s
# epoch 11 | loss: 1.00032 | validation_logloss: 1.80797 |  0:00:02s
# epoch 12 | loss: 0.95714 | validation_logloss: 1.73121 |  0:00:03s
# epoch 13 | loss: 0.96756 | validation_logloss: 1.47223 |  0:00:03s
# epoch 14 | loss: 0.9789  | validation_logloss: 1.65677 |  0:00:03s
# epoch 15 | loss: 0.98448 | validation_logloss: 1.29369 |  0:00:03s
# epoch 16 | loss: 0.97777 | validation_logloss: 1.37743 |  0:00:04s
# epoch 17 | loss: 0.95021 | validation_logloss: 1.14073 |  0:00:04s
# epoch 18 | loss: 0.95407 | validation_logloss: 1.21764 |  0:00:04s
# epoch 19 | loss: 0.97624 | validation_logloss: 1.24604 |  0:00:04s
# epoch 20 | loss: 0.90817 | validation_logloss: 1.11942 |  0:00:04s
# epoch 21 | loss: 0.92186 | validation_logloss: 1.35632 |  0:00:05s
# epoch 22 | loss: 0.90772 | validation_logloss: 1.24459 |  0:00:05s
# epoch 23 | loss: 0.91136 | validation_logloss: 1.41201 |  0:00:05s
# epoch 24 | loss: 0.89781 | validation_logloss: 1.28935 |  0:00:05s
# epoch 25 | loss: 0.89018 | validation_logloss: 1.03639 |  0:00:06s
# epoch 26 | loss: 0.87598 | validation_logloss: 1.12112 |  0:00:06s
# epoch 27 | loss: 0.87389 | validation_logloss: 1.07001 |  0:00:06s
# epoch 28 | loss: 0.87619 | validation_logloss: 1.09182 |  0:00:07s
# epoch 29 | loss: 0.87412 | validation_logloss: 1.10231 |  0:00:07s
# epoch 30 | loss: 0.87687 | validation_logloss: 1.03177 |  0:00:07s
# epoch 31 | loss: 0.89809 | validation_logloss: 1.03697 |  0:00:07s
# epoch 32 | loss: 0.88083 | validation_logloss: 1.0371  |  0:00:08s
# epoch 33 | loss: 0.89468 | validation_logloss: 0.97923 |  0:00:08s
# epoch 34 | loss: 0.8835  | validation_logloss: 0.99173 |  0:00:08s
# epoch 35 | loss: 0.87321 | validation_logloss: 0.98022 |  0:00:08s
# epoch 36 | loss: 0.87412 | validation_logloss: 0.9592  |  0:00:09s
# epoch 37 | loss: 0.87529 | validation_logloss: 0.99485 |  0:00:09s
# epoch 38 | loss: 0.88309 | validation_logloss: 1.00008 |  0:00:09s
# epoch 39 | loss: 0.87543 | validation_logloss: 1.0225  |  0:00:09s
# epoch 40 | loss: 0.86412 | validation_logloss: 0.97991 |  0:00:10s
# epoch 41 | loss: 0.87501 | validation_logloss: 0.98097 |  0:00:10s
# epoch 42 | loss: 0.87501 | validation_logloss: 0.94773 |  0:00:10s
# epoch 43 | loss: 0.87673 | validation_logloss: 0.96932 |  0:00:10s
# epoch 44 | loss: 0.86475 | validation_logloss: 0.95319 |  0:00:10s
# epoch 45 | loss: 0.85859 | validation_logloss: 0.93422 |  0:00:11s
# epoch 46 | loss: 0.85488 | validation_logloss: 0.9608  |  0:00:11s
# epoch 47 | loss: 0.85919 | validation_logloss: 0.95665 |  0:00:11s
# epoch 48 | loss: 0.85862 | validation_logloss: 0.97323 |  0:00:11s
# epoch 49 | loss: 0.87125 | validation_logloss: 0.95121 |  0:00:12s
# epoch 50 | loss: 0.86445 | validation_logloss: 0.96026 |  0:00:12s
# epoch 51 | loss: 0.86571 | validation_logloss: 0.93796 |  0:00:12s
# epoch 52 | loss: 0.8531  | validation_logloss: 0.92544 |  0:00:12s
# epoch 53 | loss: 0.86183 | validation_logloss: 0.91801 |  0:00:13s
# epoch 54 | loss: 0.85257 | validation_logloss: 0.89    |  0:00:13s
# epoch 55 | loss: 0.8667  | validation_logloss: 0.90377 |  0:00:13s
# epoch 56 | loss: 0.85545 | validation_logloss: 0.91566 |  0:00:13s
# epoch 57 | loss: 0.84172 | validation_logloss: 0.88943 |  0:00:13s
# epoch 58 | loss: 0.84401 | validation_logloss: 0.88315 |  0:00:14s
# epoch 59 | loss: 0.8569  | validation_logloss: 0.93719 |  0:00:14s
# epoch 60 | loss: 0.86408 | validation_logloss: 0.89541 |  0:00:14s
# epoch 61 | loss: 0.86241 | validation_logloss: 0.89351 |  0:00:14s
# epoch 62 | loss: 0.85419 | validation_logloss: 0.95324 |  0:00:15s
# epoch 63 | loss: 0.85645 | validation_logloss: 0.90017 |  0:00:15s
# epoch 64 | loss: 0.85872 | validation_logloss: 0.90431 |  0:00:15s
# epoch 65 | loss: 0.84785 | validation_logloss: 0.91679 |  0:00:15s
# epoch 66 | loss: 0.84906 | validation_logloss: 0.88451 |  0:00:16s
# epoch 67 | loss: 0.84375 | validation_logloss: 0.88464 |  0:00:16s
# epoch 68 | loss: 0.84286 | validation_logloss: 0.88988 |  0:00:16s
# epoch 69 | loss: 0.84725 | validation_logloss: 0.8949  |  0:00:16s
# epoch 70 | loss: 0.83439 | validation_logloss: 0.88818 |  0:00:16s
# epoch 71 | loss: 0.8422  | validation_logloss: 0.88432 |  0:00:17s
# epoch 72 | loss: 0.83695 | validation_logloss: 0.89591 |  0:00:17s
# epoch 73 | loss: 0.8446  | validation_logloss: 0.88458 |  0:00:17s
# epoch 74 | loss: 0.83661 | validation_logloss: 0.86817 |  0:00:18s
# epoch 75 | loss: 0.83061 | validation_logloss: 0.87758 |  0:00:18s
# epoch 76 | loss: 0.83016 | validation_logloss: 0.87108 |  0:00:18s
# epoch 77 | loss: 0.83968 | validation_logloss: 0.89382 |  0:00:18s
# epoch 78 | loss: 0.83426 | validation_logloss: 0.88831 |  0:00:18s
# epoch 79 | loss: 0.84575 | validation_logloss: 0.89647 |  0:00:19s
# epoch 80 | loss: 0.83781 | validation_logloss: 0.87239 |  0:00:19s
# epoch 81 | loss: 0.82244 | validation_logloss: 0.87015 |  0:00:19s
# epoch 82 | loss: 0.82993 | validation_logloss: 0.8873  |  0:00:19s
# epoch 83 | loss: 0.83428 | validation_logloss: 0.88905 |  0:00:20s
# epoch 84 | loss: 0.83411 | validation_logloss: 0.88807 |  0:00:20s
# epoch 85 | loss: 0.83334 | validation_logloss: 0.88956 |  0:00:20s
# epoch 86 | loss: 0.8333  | validation_logloss: 0.89456 |  0:00:20s
# epoch 87 | loss: 0.8284  | validation_logloss: 0.8872  |  0:00:21s
# epoch 88 | loss: 0.81739 | validation_logloss: 0.91268 |  0:00:21s
# epoch 89 | loss: 0.83437 | validation_logloss: 0.89423 |  0:00:21s
# epoch 90 | loss: 0.83246 | validation_logloss: 0.89705 |  0:00:21s
# epoch 91 | loss: 0.83112 | validation_logloss: 0.92783 |  0:00:21s
# epoch 92 | loss: 0.8365  | validation_logloss: 0.91622 |  0:00:22s
# epoch 93 | loss: 0.82331 | validation_logloss: 0.89312 |  0:00:22s
# epoch 94 | loss: 0.82489 | validation_logloss: 0.89385 |  0:00:22s
#
# Early stopping occurred at epoch 94 with best_epoch = 74 and best_validation_logloss = 0.86817
# Fold 4 - Train QWK: 0.3536, Validation QWK: 0.3465
# Training fold 5
# epoch 0  | loss: 1.82319 | validation_logloss: 5.35408 |  0:00:00s
# epoch 1  | loss: 1.46841 | validation_logloss: 3.86432 |  0:00:00s
# epoch 2  | loss: 1.4074  | validation_logloss: 3.01166 |  0:00:00s
# epoch 3  | loss: 1.32102 | validation_logloss: 4.12781 |  0:00:00s
# epoch 4  | loss: 1.16835 | validation_logloss: 3.22685 |  0:00:01s
# epoch 5  | loss: 1.10831 | validation_logloss: 2.99261 |  0:00:01s
# epoch 6  | loss: 1.05301 | validation_logloss: 2.66272 |  0:00:01s
# epoch 7  | loss: 1.03686 | validation_logloss: 2.03696 |  0:00:01s
# epoch 8  | loss: 1.02137 | validation_logloss: 2.5013  |  0:00:02s
# epoch 9  | loss: 1.00211 | validation_logloss: 1.44256 |  0:00:02s
# epoch 10 | loss: 1.03114 | validation_logloss: 1.88263 |  0:00:02s
# epoch 11 | loss: 1.00413 | validation_logloss: 1.42077 |  0:00:02s
# epoch 12 | loss: 0.9649  | validation_logloss: 1.74897 |  0:00:03s
# epoch 13 | loss: 0.95895 | validation_logloss: 1.30818 |  0:00:03s
# epoch 14 | loss: 0.93984 | validation_logloss: 1.25697 |  0:00:03s
# epoch 15 | loss: 0.91875 | validation_logloss: 1.18663 |  0:00:03s
# epoch 16 | loss: 0.92679 | validation_logloss: 1.19461 |  0:00:03s
# epoch 17 | loss: 0.94081 | validation_logloss: 1.46696 |  0:00:04s
# epoch 18 | loss: 0.91556 | validation_logloss: 1.5534  |  0:00:04s
# epoch 19 | loss: 0.90897 | validation_logloss: 1.80274 |  0:00:04s
# epoch 20 | loss: 0.9251  | validation_logloss: 1.27473 |  0:00:04s
# epoch 21 | loss: 0.94853 | validation_logloss: 1.29123 |  0:00:05s
# epoch 22 | loss: 1.0149  | validation_logloss: 1.28063 |  0:00:05s
# epoch 23 | loss: 0.93562 | validation_logloss: 1.12594 |  0:00:05s
# epoch 24 | loss: 0.8995  | validation_logloss: 1.17691 |  0:00:05s
# epoch 25 | loss: 0.90165 | validation_logloss: 1.1916  |  0:00:06s
# epoch 26 | loss: 0.89804 | validation_logloss: 1.08413 |  0:00:06s
# epoch 27 | loss: 0.87384 | validation_logloss: 1.05035 |  0:00:06s
# epoch 28 | loss: 0.87759 | validation_logloss: 1.11407 |  0:00:06s
# epoch 29 | loss: 0.8878  | validation_logloss: 1.09339 |  0:00:06s
# epoch 30 | loss: 0.89063 | validation_logloss: 1.07367 |  0:00:07s
# epoch 31 | loss: 0.89688 | validation_logloss: 1.14623 |  0:00:07s
# epoch 32 | loss: 0.88392 | validation_logloss: 1.07198 |  0:00:07s
# epoch 33 | loss: 0.85863 | validation_logloss: 1.1318  |  0:00:07s
# epoch 34 | loss: 0.86965 | validation_logloss: 1.01838 |  0:00:08s
# epoch 35 | loss: 0.86353 | validation_logloss: 1.05695 |  0:00:08s
# epoch 36 | loss: 0.87404 | validation_logloss: 1.06292 |  0:00:08s
# epoch 37 | loss: 0.87134 | validation_logloss: 0.98088 |  0:00:08s
# epoch 38 | loss: 0.87681 | validation_logloss: 1.04861 |  0:00:09s
# epoch 39 | loss: 0.87021 | validation_logloss: 0.95774 |  0:00:09s
# epoch 40 | loss: 0.86108 | validation_logloss: 1.02691 |  0:00:09s
# epoch 41 | loss: 0.85661 | validation_logloss: 0.97975 |  0:00:09s
# epoch 42 | loss: 0.87373 | validation_logloss: 0.98005 |  0:00:09s
# epoch 43 | loss: 0.8585  | validation_logloss: 0.93257 |  0:00:10s
# epoch 44 | loss: 0.865   | validation_logloss: 0.94266 |  0:00:10s
# epoch 45 | loss: 0.86644 | validation_logloss: 0.9374  |  0:00:10s
# epoch 46 | loss: 0.87058 | validation_logloss: 0.96599 |  0:00:10s
# epoch 47 | loss: 0.86595 | validation_logloss: 0.9566  |  0:00:11s
# epoch 48 | loss: 0.85325 | validation_logloss: 0.93584 |  0:00:11s
# epoch 49 | loss: 0.85903 | validation_logloss: 0.96686 |  0:00:11s
# epoch 50 | loss: 0.8747  | validation_logloss: 0.89497 |  0:00:11s
# epoch 51 | loss: 0.89102 | validation_logloss: 0.91892 |  0:00:12s
# epoch 52 | loss: 0.86659 | validation_logloss: 0.94791 |  0:00:12s
# epoch 53 | loss: 0.87463 | validation_logloss: 0.89801 |  0:00:12s
# epoch 54 | loss: 0.86376 | validation_logloss: 0.90208 |  0:00:12s
# epoch 55 | loss: 0.87373 | validation_logloss: 0.89016 |  0:00:12s
# epoch 56 | loss: 0.88013 | validation_logloss: 0.89547 |  0:00:13s
# epoch 57 | loss: 0.86306 | validation_logloss: 0.89006 |  0:00:13s
# epoch 58 | loss: 0.86646 | validation_logloss: 0.88644 |  0:00:13s
# epoch 59 | loss: 0.87264 | validation_logloss: 0.89301 |  0:00:13s
# epoch 60 | loss: 0.86188 | validation_logloss: 0.88232 |  0:00:14s
# epoch 61 | loss: 0.85993 | validation_logloss: 0.88291 |  0:00:14s
# epoch 62 | loss: 0.85275 | validation_logloss: 0.88466 |  0:00:14s
# epoch 63 | loss: 0.8567  | validation_logloss: 0.88131 |  0:00:14s
# epoch 64 | loss: 0.84897 | validation_logloss: 0.86518 |  0:00:15s
# epoch 65 | loss: 0.85582 | validation_logloss: 0.87508 |  0:00:15s
# epoch 66 | loss: 0.85149 | validation_logloss: 0.87484 |  0:00:15s
# epoch 67 | loss: 0.85936 | validation_logloss: 0.88941 |  0:00:15s
# epoch 68 | loss: 0.86542 | validation_logloss: 0.89232 |  0:00:16s
# epoch 69 | loss: 0.87546 | validation_logloss: 0.90134 |  0:00:16s
# epoch 70 | loss: 0.87671 | validation_logloss: 0.87613 |  0:00:16s
# epoch 71 | loss: 0.87534 | validation_logloss: 0.86728 |  0:00:16s
# epoch 72 | loss: 0.87415 | validation_logloss: 0.87176 |  0:00:17s
# epoch 73 | loss: 0.86571 | validation_logloss: 0.85674 |  0:00:17s
# epoch 74 | loss: 0.8741  | validation_logloss: 0.86537 |  0:00:17s
# epoch 75 | loss: 0.86881 | validation_logloss: 0.86359 |  0:00:17s
# epoch 76 | loss: 0.8642  | validation_logloss: 0.87208 |  0:00:18s
# epoch 77 | loss: 0.86437 | validation_logloss: 0.86125 |  0:00:18s
# epoch 78 | loss: 0.85801 | validation_logloss: 0.87585 |  0:00:18s
# epoch 79 | loss: 0.8621  | validation_logloss: 0.85137 |  0:00:18s
# epoch 80 | loss: 0.86455 | validation_logloss: 0.86923 |  0:00:18s
# epoch 81 | loss: 0.85963 | validation_logloss: 0.89363 |  0:00:19s
# epoch 82 | loss: 0.86243 | validation_logloss: 0.89411 |  0:00:19s
# epoch 83 | loss: 0.86025 | validation_logloss: 0.86646 |  0:00:19s
# epoch 84 | loss: 0.86556 | validation_logloss: 0.85888 |  0:00:19s
# epoch 85 | loss: 0.85649 | validation_logloss: 0.85725 |  0:00:20s
# epoch 86 | loss: 0.86219 | validation_logloss: 0.84814 |  0:00:20s
# epoch 87 | loss: 0.8595  | validation_logloss: 0.85299 |  0:00:20s
# epoch 88 | loss: 0.85986 | validation_logloss: 0.86657 |  0:00:20s
# epoch 89 | loss: 0.85819 | validation_logloss: 0.8739  |  0:00:20s
# epoch 90 | loss: 0.86873 | validation_logloss: 0.86497 |  0:00:21s
# epoch 91 | loss: 0.86064 | validation_logloss: 0.87832 |  0:00:21s
# epoch 92 | loss: 0.86748 | validation_logloss: 0.86943 |  0:00:21s
# epoch 93 | loss: 0.86971 | validation_logloss: 0.88956 |  0:00:21s
# epoch 94 | loss: 0.87569 | validation_logloss: 0.85517 |  0:00:22s
# epoch 95 | loss: 0.87917 | validation_logloss: 0.8581  |  0:00:22s
# epoch 96 | loss: 0.87645 | validation_logloss: 0.85437 |  0:00:22s
# epoch 97 | loss: 0.86327 | validation_logloss: 0.85704 |  0:00:22s
# epoch 98 | loss: 0.86768 | validation_logloss: 0.85365 |  0:00:22s
# epoch 99 | loss: 0.85413 | validation_logloss: 0.8477  |  0:00:23s
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_validation_logloss = 0.8477
# Fold 5 - Train QWK: 0.2875, Validation QWK: 0.2908
# Average Train QWK: 0.3548
# Average Validation QWK: 0.3258
# Optimized Thresholds: [0.66838349 1.02488426 2.2890625 ]
# Final Optimized QWK: 0.3916
